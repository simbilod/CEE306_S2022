# %% [markdown]
# ## External package usecase: Pandas
#
# We again import pandas:

# %%
import pandas as pd

# %% [markdown]
# Again import the csv file:

# %%
myfile_variable = pd.read_csv("Traffic_Violations-short.csv", delimiter="|")

# %% [markdown]
# We would like to visually look at the data instead of printing it. In addition to attributes, objects (like Dataframes) also have methods, which are functions that act onto said objects. They are listed in the documentation, https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html, and one of them is used for quick plots:

# %%
myfile_variable.plot?
# Out:
# Signature:      myfile_variable.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x000001FB590D2430>
# File:           c:\users\simon\appdata\local\continuum\anaconda3\envs\thinfilm\lib\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
# ...

# %%
myfile_variable.plot(x='Date Of Stop', y='Latitude', kind='bar')
# Out:
# <AxesSubplot:xlabel='Date Of Stop'>

# %% [markdown]
# There is a much better example in this week's assignment Notebook for you to look at. There are purpose-built packages for data visualization in Python like `matplotlib`; this will be a topic next week.
